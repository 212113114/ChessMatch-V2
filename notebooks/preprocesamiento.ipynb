# %%
#!pip install python-chess

# %%
import os
import zipfile
import pandas as pd
import chess.pgn
from io import TextIOWrapper

# === Configuración ===
zip_folder = "pgns"
os.makedirs("pgns_extracted", exist_ok=True)  # No usado, pero por si luego se quiere guardar
game_counter = 0

# === Contenedores de resultados ===
all_games_info = []
player_moves_data = []

# === Proceso de extracción ===
for zip_name in sorted(os.listdir(zip_folder)):
    if not zip_name.endswith(".zip"):
        continue

    player_lastname = os.path.splitext(zip_name)[0]  # "Carlsen", "Kasparov", etc.
    zip_path = os.path.join(zip_folder, zip_name)

    with zipfile.ZipFile(zip_path, 'r') as archive:
        for pgn_filename in archive.namelist():
            if not pgn_filename.endswith(".pgn"):
                continue

            with archive.open(pgn_filename) as file:
                text_io = TextIOWrapper(file, encoding='utf-8', errors='ignore')
                while True:
                    game = chess.pgn.read_game(text_io)
                    if game is None:
                        break

                    board = game.board()
                    moves = []
                    for move in game.mainline_moves():
                        try:
                            san = board.san(move)
                        except Exception:
                            san = None  # jugada inválida
                        if san:
                            moves.append(san)
                        board.push(move)

                    white = game.headers.get("White", "").lower()
                    black = game.headers.get("Black", "").lower()
                    lastname_lower = player_lastname.lower()

                    # Determinar si el jugador del archivo es blanco o negro
                    if lastname_lower in white:
                        player_color = "white"
                        player_moves = moves[::2]
                    elif lastname_lower in black:
                        player_color = "black"
                        player_moves = moves[1::2]
                    else:
                        continue  # Si el jugador no aparece como blanco ni negro, saltamos

                    # === Guardar en ambos dataframes ===
                    game_id = game_counter

                    all_games_info.append({
                        "id": game_id,
                        "white": game.headers.get("White", ""),
                        "black": game.headers.get("Black", ""),
                        "result": game.headers.get("Result", ""),
                        "event": game.headers.get("Event", ""),
                        "date": game.headers.get("Date", ""),
                        "player_file": player_lastname,
                        "full_moves": " ".join(moves),  # <-- todos los movimientos SAN
})

                    player_moves_data.append({
                        "id": game_id,
                        "player": player_lastname,
                        "color": player_color,
                        "moves": " ".join(player_moves),
                    })

                    game_counter += 1

# === Crear DataFrames ===
df_all_games = pd.DataFrame(all_games_info)
df_player_moves = pd.DataFrame(player_moves_data)


# === Guardar a CSV (opcional) ===
df_all_games.to_csv("csvs/games.csv", index=False)
df_player_moves.to_csv("csvs/player_moves.csv", index=False)


print(f"Partidas procesadas: {len(df_all_games)}")
# Out:
# illegal san: 'Qxe1' in r2k3r/2pPp3/p4n2/3b2B1/1p5P/2qP4/3RQ1P1/4K2R w - - 2 31 while parsing <Game at 0x19cae4ce180 ('Gelfand,B' vs. 'Gareev,T', '2019.12.29' at 'Moscow RUS')>
# Partidas procesadas: 99897

# %%
df_all_games
# Out:
#           id                        white                        black  \
# 0          0                       Savrov          Alekhine, Alexander
# 1          1                        Giese          Alekhine, Alexander
# 2          2          Alekhine, Alexander                 Ljubimov, T.
# 3          3          Alekhine, Alexander                   Romaskevic
# 4          4                    Manko, V.          Alekhine, Alexander
# ...      ...                          ...                          ...
# 99892  99892  Zukertort, Johannes Hermann     Blackburne, Joseph Henry
# 99893  99893     Blackburne, Joseph Henry  Zukertort, Johannes Hermann
# 99894  99894  Zukertort, Johannes Hermann     Blackburne, Joseph Henry
# 99895  99895     Blackburne, Joseph Henry  Zukertort, Johannes Hermann
# 99896  99896  Zukertort, Johannes Hermann     Blackburne, Joseph Henry
#
#         result       event        date player_file  \
# 0          0-1  Earl tourn  1906.??.??    Alekhine
# 1          0-1  Earl tourn  1906.??.??    Alekhine
# 2          1-0  Earl tourn  1906.??.??    Alekhine
# 3          1-0  Earl tourn  1906.??.??    Alekhine
# 4          1-0  Earl tourn  1906.??.??    Alekhine
# ...        ...         ...         ...         ...
# 99892      0-1    London m  1887.??.??   Zukertort
# 99893  1/2-1/2    London m  1887.??.??   Zukertort
# 99894  1/2-1/2    London m  1887.??.??   Zukertort
# 99895  1/2-1/2    London m  1887.??.??   Zukertort
# 99896      0-1    London m  1887.??.??   Zukertort
#
#                                               full_moves
# 0      e4 e5 f4 Bc5 Nf3 d6 c3 Bg4 Be2 Bxf3 Bxf3 Nc6 b...
# 1      e4 e5 Nf3 Nc6 d4 exd4 Nxd4 Nf6 Nc3 Bb4 Nxc6 bx...
# 2      e4 e5 Nf3 Nc6 Bc4 Nf6 Ng5 d5 exd5 Na5 Bb5+ c6 ...
# 3      e4 e5 Ne2 f5 Ng3 Qh4 Nc3 Bc5 Qf3 d6 exf5 Ne7 N...
# 4      e4 e5 Nf3 Nc6 Bc4 Bc5 b4 Bxb4 c3 Ba5 d4 exd4 O...
# ...                                                  ...
# 99892  d4 d5 e3 Nf6 c4 e6 Nf3 c5 b3 Nc6 Bb2 cxd4 exd4...
# 99893  e4 e5 Nf3 Nc6 Bb5 Nf6 d3 d6 O-O g6 Nc3 Bd7 Bg5...
# 99894  c4 e5 e3 Nc6 a3 g6 Nc3 Bg7 Nf3 Nge7 Be2 d5 cxd...
# 99895  d4 d5 c4 e6 Nc3 Nf6 Bf4 c5 e3 Nc6 Nf3 cxd4 exd...
# 99896  c4 e5 e3 Nc6 a3 g6 Nc3 Bg7 g3 Nge7 Bg2 d6 Nge2...
#
# [99897 rows x 8 columns]

# %%
df_player_moves
# Out:
#           id     player  color  \
# 0          0   Alekhine  black
# 1          1   Alekhine  black
# 2          2   Alekhine  white
# 3          3   Alekhine  white
# 4          4   Alekhine  black
# ...      ...        ...    ...
# 99892  99892  Zukertort  white
# 99893  99893  Zukertort  black
# 99894  99894  Zukertort  white
# 99895  99895  Zukertort  black
# 99896  99896  Zukertort  white
#
#                                                    moves
# 0      e5 Bc5 d6 Bg4 Bxf3 Nc6 Bb6 Nce7 exd4 Nf6 O-O d...
# 1      e5 Nc6 exd4 Nf6 Bb4 bxc6 Qe7 d5 O-O Bc5 gxf6 B...
# 2      e4 Nf3 Bc4 Ng5 exd5 Bb5+ dxc6 Qf3 Bd3 Ne4 Ng3 ...
# 3      e4 Ne2 Ng3 Nc3 Qf3 exf5 Nce4 c3 d4 Nh5 Nhf6+ g...
# 4      e5 Nc6 Bc5 Bxb4 Ba5 exd4 dxc3 Qf6 Qg6 Nge7 Rb8...
# ...                                                  ...
# 99892  d4 e3 c4 Nf3 b3 Bb2 exd4 bxc4 Nbd2 Qa4 Rd1 Bd3...
# 99893  e5 Nc6 Nf6 d6 g6 Bd7 Bg7 h6 Bxf6 Bg7 O-O Ne7 N...
# 99894  c4 e3 a3 Nc3 Nf3 Be2 cxd5 O-O Qc2 bxc3 d3 e4 h...
# 99895  d5 e6 Nf6 c5 Nc6 cxd4 dxc4 Be7 O-O Bd7 Rc8 Qa5...
# 99896  c4 e3 a3 Nc3 g3 Bg2 Nge2 Nd5 d3 O-O d4 Nxe7+ d...
#
# [99897 rows x 4 columns]

# %%
df_player_moves["player"].value_counts()
# Out:
# player
# Kamsky         7035
# Carlsen        6615
# Caruana        5340
# Aronian        5107
# Ivanchuk       4950
# Kramnik        4324
# Anand          4204
# Gelfand        3983
# Timman         3621
# Karjakin       3536
# Karpov         3529
# Portisch       3030
# Leko           2681
# Smyslov        2627
# Topalov        2613
# Tal            2431
# Larsen         2383
# Spassky        2231
# Geller         2198
# Kasparov       2128
# Bronstein      1930
# Petrosian      1893
# Polugaevsky    1890
# Alekhine       1661
# Najdorf        1604
# Keres          1571
# Reshevsky      1267
# Euwe           1122
# Korchnoi       1038
# Bogoljubow      973
# Lasker          900
# Botvinnik       891
# Fischer         827
# Rubinstein      797
# Maroczy         756
# Schlechter      739
# Tarrasch        704
# Chigorin        688
# Anderssen       681
# Capablanca      597
# Steinitz        590
# Nimzowitsch     512
# Pillsbury       388
# Fine            305
# Staunton        284
# Zukertort       265
# Winawer         241
# Morphy          211
# Philidor          6
# Name: count, dtype: int64

# %%
#!pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (2.2.2)
# Requirement already satisfied: sentencepiece in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: torchvision in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (0.16.0)
# Requirement already satisfied: nltk in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: scikit-learn in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (4.35.0)
# Requirement already satisfied: scipy in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: tqdm in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: numpy in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (1.24.3)
# Requirement already satisfied: torch>=1.6.0 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sentence-transformers) (2.1.0)
# Requirement already satisfied: requests in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: fsspec in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: filelock in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.13.2)
# Requirement already satisfied: networkx in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from torch>=1.6.0->sentence-transformers) (2.8.8)
# Requirement already satisfied: jinja2 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: sympy in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.14.1)
# Requirement already satisfied: click in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from torchvision->sentence-transformers) (10.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/franciscomeza/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sentence_transformers
import pandas as pd
import os

# %%
# Move one directory up to access the 'csvs' folder
os.chdir("..")

# %% [markdown]
# ### SBERT

# %%
def vectorizar(jugadas):
    modelo = sentence_transformers.SentenceTransformer("bert-base-nli-mean-tokens")
    return  modelo.encode(jugadas)

# %%
df_player_moves = pd.read_csv("csvs/player_moves.csv")
df_player_moves["moves"] = df_player_moves["moves"].apply(vectorizar)
df_player_moves
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 df_player_moves = pd.read_csv("csvs/player_moves.csv")
# ----> 2 df_player_moves["moves"] = df_player_moves["moves"].apply(vectorizar)
#       3 df_player_moves
#
# File ~/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[3], line 3, in vectorizar(jugadas)
#       1 def vectorizar(jugadas):
#       2     modelo = sentence_transformers.SentenceTransformer("bert-base-nli-mean-tokens")
# ----> 3     return  modelo.encode(jugadas)
#
# File ~/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages/sentence_transformers/SentenceTransformer.py:161, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     159 for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#     160     sentences_batch = sentences_sorted[start_index:start_index+batch_size]
# --> 161     features = self.tokenize(sentences_batch)
#     162     features = batch_to_device(features, device)
#     164     with torch.no_grad():
#
# File ~/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages/sentence_transformers/SentenceTransformer.py:319, in SentenceTransformer.tokenize(self, texts)
#     315 def tokenize(self, texts: Union[List[str], List[Dict], List[Tuple[str, str]]]):
#     316     """
#     317     Tokenizes the texts
#     318     """
# --> 319     return self._first_module().tokenize(texts)
#
# File ~/.pyenv/versions/3.8.18/envs/mining-project/lib/python3.8/site-packages/sentence_transformers/models/Transformer.py:102, in Transformer.tokenize(self, texts)
#     100 batch1, batch2 = [], []
#     101 for text_tuple in texts:
# --> 102     batch1.append(text_tuple[0])
#     103     batch2.append(text_tuple[1])
#     104 to_tokenize = [batch1, batch2]
#
# TypeError: 'float' object is not subscriptable

# %%
df_player_moves.to_csv("vectorized_player_moves.csv", index=False)
