# %%
#Asegurar que el código sea reproducible
import random
import numpy as np
import torch

SEED = 3633

#Semilla para Python
random.seed(SEED)

#Semilla para NumPy
np.random.seed(SEED)

# Semilla para PyTorch
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
#Cargamos los modelos y datos
import pickle
import pandas as pd

with open("modelos/kmeans_games.pkl", "rb") as f:
    kmeans_games = pickle.load(f)
with open("modelos/kmeans_players.pkl", "rb") as f:
    kmeans_players = pickle.load(f)

player_embeddings = pd.read_csv("csvs/player_embeddings.csv")
games = pd.read_csv("csvs/games_metadata_gnn.csv")
games_embeddings = pd.read_csv("csvs/embeddings_gnn.csv")
# Out:
# C:\Users\B\AppData\Local\Temp\ipykernel_20868\1112781581.py:11: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   games = pd.read_csv("csvs/games_metadata_gnn.csv")

# %%
import os
import zipfile
import chess.pgn
from io import TextIOWrapper
from torch_geometric.data import Data




# =====================
# FUNCIÓN DE FEATURES
# =====================

def board_to_feature(board):
    """Convierte el estado del tablero a un vector de 773 features"""
    piece_map = board.piece_map()
    planes = np.zeros((12, 64), dtype=np.float32)
    piece_to_index = {
        'P': 0, 'N': 1, 'B': 2, 'R': 3, 'Q': 4, 'K': 5,
        'p': 6, 'n': 7, 'b': 8, 'r': 9, 'q': 10, 'k': 11
    }
    for square, piece in piece_map.items():
        planes[piece_to_index[piece.symbol()]][square] = 1.0
    flat_pieces = planes.reshape(-1)  # 768

    extras = [
        float(board.turn),
        float(board.has_kingside_castling_rights(chess.WHITE)),
        float(board.has_queenside_castling_rights(chess.WHITE)),
        float(board.has_kingside_castling_rights(chess.BLACK)),
        float(board.has_queenside_castling_rights(chess.BLACK)),
    ]
    return np.concatenate([flat_pieces, extras])  # 773

# =====================
# FUNCIÓN PARA GRAFO DE PARTIDA
# =====================

def pgn_to_graph_one_player(game, color):
    board = game.board()
    x = []
    edge_index = [[], []]
    node_idx = 0
    move_idx = 0

    for move in game.mainline_moves():
        board.push(move)
        if (color == "white" and move_idx % 2 == 0) or (color == "black" and move_idx % 2 == 1):
            x.append(board_to_feature(board.copy()))
            if node_idx > 0:
                edge_index[0].append(node_idx - 1)
                edge_index[1].append(node_idx)
            node_idx += 1
        move_idx += 1

    if len(x) < 2:
        return None

    x = torch.tensor(np.stack(x), dtype=torch.float)
    edge_index = torch.tensor(edge_index, dtype=torch.long)
    return Data(x=x, edge_index=edge_index)

def process_single_pgn(pgn_path, target_player):
    data_graphs = []
    game_id = 0

    with open(pgn_path, encoding='utf-8', errors='ignore') as f:
        while True:
            game = chess.pgn.read_game(f)
            if game is None:
                break

            white = game.headers.get("White", "").lower()
            black = game.headers.get("Black", "").lower()
            target = target_player.lower()

            if target == white:
                color = "white"
            elif target == black:
                color = "black"
            else:
                print(f"El jugador {target_player} no está en esta partida.")
                continue

            graph = pgn_to_graph_one_player(game, color)
            if graph:
                graph.player = target_player
                graph.game_id = game_id
                data_graphs.append(graph)
                game_id += 1  
    print(f"Utilizando {len(data_graphs)} partidas de {target_player}")
    return data_graphs

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool
from torch_geometric.loader import DataLoader
import pandas as pd
from tqdm import tqdm

# ======================
# Hiperparámetros
# ======================
INPUT_DIM = 773
HIDDEN_DIM = 256
EMBED_DIM = 128
BATCH_SIZE = 32

# ======================
# Modelo GCN Encoder
# ======================
class GNNEncoder(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, x, edge_index, batch):
        x = F.relu(self.conv1(x, edge_index))
        x = self.conv2(x, edge_index)
        return global_mean_pool(x, batch)

# %%
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity


def make_recommendations(player_name, pgn_path, n_players, n_games):
    print("Leyendo partidas...")
    #Crear grafos
    graphs_list = process_single_pgn(pgn_path, player_name)
    # Cargar grafos
    loader = DataLoader(graphs_list, batch_size=BATCH_SIZE, shuffle=False)

    model = GNNEncoder(INPUT_DIM, HIDDEN_DIM, EMBED_DIM)
    model.eval()

    # ======================
    # Embedding loop
    # ======================
    embeddings = []
    players = []
    game_ids = []

    with torch.no_grad():
        for batch in tqdm(loader, desc="Generando embeddings"):
            z = model(batch.x, batch.edge_index, batch.batch)
            embeddings.append(z)
            graphs_in_batch = batch.to_data_list()
            players += [g.player for g in graphs_in_batch]
            game_ids += [g.game_id for g in graphs_in_batch]

    embeddings = torch.cat(embeddings).cpu().numpy()


    data = pd.DataFrame(embeddings, columns=[f"dim_{i}" for i in range(EMBED_DIM)])
    embedding_columns = [f"dim_{i}" for i in range(128)]
    data['embedding'] = data[embedding_columns].values.tolist()
    X = np.stack(data['embedding'].values)

    labels = kmeans_games.predict(X)

    
    #Crear vector para el usuario

    labels = kmeans_games.predict(X)
    counts = Counter(labels)
    cluster_vector = np.zeros(kmeans_games.n_clusters)

    for cluster_id, count in counts.items():
        cluster_vector[cluster_id] = count

    cluster_vector = cluster_vector / cluster_vector.sum()

    #Recomendacion de Estilo (Cluster)
    estilo = kmeans_players.predict(cluster_vector.reshape(1, -1))[0]
    print("\nTu estilo es:")
    if estilo == 0:
        print("🟦 Cluster 0 – “Vanguardia del Ajedrez Moderno”")
        print("Descripción: Jugadores que transicionaron entre el ajedrez clásico y el pensamiento moderno. Mezclan elegancia posicional con creatividad táctica.")
        print("Estilo: Creatividad estructurada, técnica refinada, inicio del pensamiento hipermoderno.")
        print("Ejemplos: Alekhine, Bogoljubow, Capablanca, Nimzowitsch, Rubinstein")

    elif estilo == 1:
        print("🟩 Cluster 1 – “Escuela Clásica y Fundacional”")
        print("Descripción: Padres fundadores del ajedrez posicional. Énfasis en principios clásicos como el control central y el desarrollo armónico.")
        print("Estilo: Clásico, científico, riguroso.")
        print("Ejemplos: Lasker, Steinitz, Tarrasch, Staunton, Chigorin")

    elif estilo == 2:
        print("🟨 Cluster 2 – “Maestros Contemporáneos del Siglo XXI”")
        print("Descripción: Jugadores modernos con un estilo universal. Alta preparación teórica, precisión y flexibilidad.")
        print("Estilo: Universal, multifacético, técnico y adaptativo.")
        print("Ejemplos: Carlsen, Anand, Kramnik, Caruana, Topalov")

    elif estilo == 3:
        print("🟠 Cluster 3 – “Escuela Posicional Soviética”")
        print("Descripción: Jugadores de la tradición soviética. Muy técnicos, con enfoque estratégico y profundo conocimiento del medio juego.")
        print("Estilo: Posicional, estructural, metódico.")
        print("Ejemplos: Botvinnik, Karpov, Petrosian, Smyslov, Gelfand")

    elif estilo == 4:
        print("🔴 Cluster 4 – “Genios Creativos y Agresivos”")
        print("Descripción: Grandes calculadores y atacantes. Estilo impredecible, dinámico y espectacular.")
        print("Estilo: Táctico, agresivo, intuitivo.")
        print("Ejemplos: Fischer, Kasparov, Tal, Bronstein, Spassky")

    else:
        print("Error")
        return


    

    #Hacer Recomendaciones de jugadores
    print("\nJugadores similares recomendados:\n")
    player_names = player_embeddings["player"]
    X_embeddings = player_embeddings.drop(columns=["player"]).values
    sims = cosine_similarity([cluster_vector], X_embeddings)[0]
    # Crear dataframe ordenado por similitud
    similarities_df = pd.DataFrame({    
        "player": player_names,
        "similarity": sims
    }).sort_values(by="similarity", ascending=False)

    recommended_players = list(similarities_df.head(n_players)["player"])
    similarities = list(similarities_df.head(n_players)["similarity"])


    #Para hacer recomendaciones de juegos
    vector_promedio = np.mean(X, axis=0).reshape(1, -1)

    for n in range(n_players):
        recommended_player = recommended_players[n]
        print(f"({n + 1}) {recommended_player} con {round(similarities[n], 2)} de similitud\n")
        print("Partidas recomendadas:\n")
        juegos = games_embeddings[games_embeddings["player"] == recommended_player].copy()


        dim_cols = [col for col in juegos.columns if col.startswith("dim_")]
        embeddings = juegos[dim_cols].values  # Convertir a matriz NumPy

    
        # Calcular similitudes de coseno entre vector promedio y juegos
        similitudes = cosine_similarity(vector_promedio, embeddings)[0]  # Solo una fila vs todas

        #Añadir similitudes al DataFrame
        juegos['cosine_similarity'] = similitudes

        #Obtener los |n_games| vectores más similares
        top = juegos.sort_values(by='cosine_similarity', ascending=False).head(n_games)
        
        ids_juegos = list(top["game_id"])
        resultados = games[games["game_id"].isin(ids_juegos)][["game_id", "pgn"]]

        pgns = list(resultados["pgn"])
        for p in pgns:
            print(p)
            print("\n")
        print("\n")

# %%
make_recommendations("B12113114" , "lichess\lichess_B12113114.pgn" , 5, 5)
# Out:
# Leyendo partidas...
# Utilizando 841 partidas de B12113114
# Generando embeddings: 100%|██████████| 27/27 [00:00<00:00, 48.48it/s]
# Tu estilo es:
# 🟩 Cluster 1 – “Escuela Clásica y Fundacional”
# Descripción: Padres fundadores del ajedrez posicional. Énfasis en principios clásicos como el control central y el desarrollo armónico.
# Estilo: Clásico, científico, riguroso.
# Ejemplos: Lasker, Steinitz, Tarrasch, Staunton, Chigorin
#
# Jugadores similares recomendados:
#
# (1) Tarrasch con 0.79 de similitud
#
# Partidas recomendadas:
#
# [Event "DSB-07.Kongress"]
# [Site "Dresden"]
# [Date "1892.??.??"]
# [Round "?"]
# [White "Tarrasch, Siegbert"]
# [Black "Marco, Georg"]
# [Result "1-0"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C66"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 d6 4. d4 Bd7 5. Nc3 Nf6 6. O-O Be7 7. Re1 O-O 8. Bxc6 Bxc6 9. dxe5 dxe5 10. Qxd8 Raxd8 11. Nxe5 Bxe4 12. Nxe4 Nxe4 13. Nd3 f5 14. f3 Bc5+ 15. Nxc5 Nxc5 16. Bg5 Rd5 17. Be7 Re8 18. c4 1-0
#
#
# [Event "Nuremberg m"]
# [Site "Nuremberg"]
# [Date "1894.??.??"]
# [Round "3"]
# [White "Walbrodt, Carl August"]
# [Black "Tarrasch, Siegbert"]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C67"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. O-O Nxe4 5. Re1 Nd6 6. Bxc6 dxc6 7. Nxe5 Be7 8. d4 O-O 9. Nc3 Nf5 10. d5 cxd5 11. Nxd5 Bd6 12. Nf3 Nh4 13. Nxh4 Qxh4 14. g3 Qh3 15. Bf4 Bc5 16. Be3 Bd6 17. Bf4 Bc5 18. Nxc7 Bg4 19. Qd5 Rad8 20. Qg2 Qxg2+ 21. Kxg2 h6 22. h3 Bd7 23. c4 Bc6+ 24. Nd5 Bxd5+ 1/2-1/2
#
#
# [Event "DSB-17.Kongress"]
# [Site "Hamburg"]
# [Date "1910.??.??"]
# [Round "1"]
# [White "Tartakower, Saviely"]
# [Black "Tarrasch, Siegbert"]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C01"]
#
# 1. c4 e6 2. e4 d5 3. exd5 exd5 4. d4 Nc6 5. Nf3 Nf6 6. Be2 dxc4 7. Bxc4 Bd6 8. O-O O-O 9. Nc3 Bg4 10. Be3 Qd7 11. Be2 Rfe8 12. Re1 Rad8 13. h3 Bh5 14. Qb3 Na5 15. Qb5 Qxb5 16. Nxb5 Nc6 17. g4 Bg6 18. Nxd6 Rxd6 19. Bb5 a6 20. Bxc6 Rxc6 21. Rac1 Rxc1 22. Rxc1 Nd5 23. Bd2 f6 24. Re1 Rxe1+ 25. Nxe1 Bb1 26. a3 Kf7 27. Ng2 Ke6 28. Nf4+ Nxf4 29. Bxf4 c6 30. a4 Kd5 31. a5 Kxd4 32. b4 Kc4 33. Bd6 Kb5 34. Bc5 Ba2 35. Kg2 Be6 36. Kf3 Bc8 37. Ke4 1/2-1/2
#
#
# [Event "Teplitz-Schoenau"]
# [Site "Teplitz-Schoenau"]
# [Date "1922.??.??"]
# [Round "1"]
# [White "Gruenfeld, Ernst"]
# [Black "Tarrasch, Siegbert"]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "D32"]
#
# 1. d4 d5 2. c4 e6 3. Nc3 c5 4. Nf3 Nc6 5. cxd5 exd5 6. dxc5 d4 7. Na4 Bxc5 8. Nxc5 Qa5+ 9. Bd2 Qxc5 10. e3 dxe3 11. Bxe3 Qb4+ 12. Qd2 Qxd2+ 13. Nxd2 Nge7 14. Bb5 O-O 15. O-O Bf5 16. Nb3 Rfd8 17. Rfd1 Bc2 18. Rxd8+ Rxd8 19. Nc5 b6 20. Rc1 Rd1+ 21. Rxd1 Bxd1 22. Ne4 Nb4 23. Bd2 Nbd5 24. Nd6 Bg4 25. Bc4 Be6 26. Nb5 Nc6 1/2-1/2
#
#
# [Event "Semmering"]
# [Site "Semmering"]
# [Date "1926.??.??"]
# [Round "?"]
# [White "Kmoch, Hans"]
# [Black "Tarrasch, Siegbert"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "D06"]
#
# 1. d4 Nf6 2. Nf3 d5 3. c4 c5 4. cxd5 cxd4 5. Qxd4 Qxd5 6. Nc3 Qa5 7. e4 Nc6 8. Bb5 Bd7 9. Qa4 Qxa4 10. Bxa4 e6 11. e5 Nd5 12. Nxd5 exd5 13. Bb3 Be6 14. O-O Be7 15. Rd1 O-O-O 16. Be3 Kb8 17. Rac1 Na5 18. Bc2 Nc4 19. Bd4 Rc8 20. Bd3 Bb4 21. Rc2 h6 22. Rdc1 Na5 23. Bc5 Bxc5 24. Rxc5 Rxc5 25. Rxc5 Nc6 26. Bb5 Rc8 27. Kf1 Ne7 28. Rxc8+ Kxc8 29. Nd4 Ng6 30. Nf3 Bg4 31. Nd4 Nxe5 32. h3 Be6 33. f4 Nc4 34. b3 Nd6 35. Bd3 Kc7 36. Ke2 Kb6 37. Ke3 Kc5 38. b4+ Kxb4 39. Nxe6 fxe6 40. Kd4 Nf7 41. f5 exf5 42. Bxf5 Nd6 43. Bd7 Nb5+ 44. Kxd5 Nc3+ 45. Ke6 Nxa2 46. Kf7 a5 47. Kxg7 a4 48. Bxa4 Kxa4 49. Kxh6 b5 50. g4 b4 51. g5 Nc3 52. Kg7 Nd5 53. g6 Nf4 54. h4 b3 55. Kh7 Nxg6 56. h5 Ne7 0-1
#
#
#
#
# (2) Lasker con 0.78 de similitud
#
# Partidas recomendadas:
#
# [Event "GBR tour sim"]
# [Site "Great Britain"]
# [Date "1898.??.??"]
# [Round "?"]
# [White "Lasker, Emanuel"]
# [Black "Holmes, H."]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C54"]
#
# 1. e4 e5 2. Nf3 Nc6 3. d4 exd4 4. Bc4 Bc5 5. c3 Nf6 6. cxd4 Bb4+ 7. Bd2 Nxe4 8. Bxb4 Nxb4 9. Qb3 d5 10. Qxb4 dxc4 11. Qxc4 O-O 12. O-O Be6 13. Qd3 Nd6 14. Re1 Re8 15. Nc3 Qf6 16. d5 Bf5 17. Qd4 Qxd4 18. Nxd4 Bd7 19. f3 Rxe1+ 20. Rxe1 Re8 21. Rxe8+ Nxe8 22. Ne4 Kf8 23. Kf2 Ke7 24. Ke3 Nd6 25. b3 a6 26. Kf4 Bc8 27. g4 f6 28. h4 1/2-1/2
#
#
# [Event "GER tour sim"]
# [Site "Germany"]
# [Date "1900.??.??"]
# [Round "?"]
# [White "Lasker, Emanuel"]
# [Black "NN"]
# [Result "1-0"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C56"]
#
# 1. e4 e5 2. Nf3 Nc6 3. d4 exd4 4. Bc4 Nf6 5. O-O Nxe4 6. Re1 d5 7. Bxd5 Qxd5 8. Nc3 Qd8 9. Rxe4+ Be6 10. Nxd4 Nxd4 11. Rxd4 Qc8 12. Qh5 Be7 13. Bg5 Bxg5 14. Qxg5 O-O 15. Ne4 Bf5 16. c4 b6 17. Ng3 Bg6 18. Rad1 Re8 19. h4 c5 20. Rd6 Qc7 21. h5 f6 22. Qg4 Bf7 23. Nf5 Be6 24. Rd7 1-0
#
#
# [Event "USA tour sim"]
# [Site "USA"]
# [Date "1903.??.??"]
# [Round "?"]
# [White "Barry, JF."]
# [Black "Lasker, Emanuel"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C65"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. d4 exd4 5. e5 Ne4 6. O-O Be7 7. Nxd4 O-O 8. c3 Nxe5 9. Qe2 d5 10. f3 c5 11. fxe4 cxd4 12. cxd4 Bg4 13. Qe3 Ng6 14. e5 f6 15. Qg3 Be6 16. Bd3 Qb6 17. Bxg6 hxg6 18. Nc3 fxe5 19. Qxe5 Rxf1+ 20. Kxf1 Bf6 21. Qe2 Bxd4 22. Bg5 Rf8+ 23. Ke1 Rf2 24. Qd1 Bxc3+ 25. bxc3 Rxg2 0-1
#
#
# [Event "USA tour sim"]
# [Site "USA"]
# [Date "1906.??.??"]
# [Round "?"]
# [White "Lasker, Emanuel"]
# [Black "Paredes"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C54"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bc4 Bc5 4. c3 Nf6 5. d4 exd4 6. cxd4 Bb4+ 7. Bd2 Nxe4 8. Bxb4 Nxb4 9. Bxf7+ Kxf7 10. Qb3+ d5 11. Ne5+ Ke6 12. Qxb4 c5 13. Qa4 Qb6 14. Nd3 c4 15. Nf4+ Kf5 16. Nxd5 Qxd4 17. Ne3+ Kg6 18. O-O Nxf2 19. Rxf2 Qxe3 20. Qc2+ Kh6 21. Nc3 Rf8 22. Rf1 Bf5 23. Qd2 Qxd2 24. Rxd2 Bd3 25. Rxf8 Rxf8 26. h3 Rf1+ 27. Kh2 Rc1 28. Nb5 a6 29. Nd4 Kg6 30. Nf3 Kf5 31. Rf2 Rf1 32. Rd2 Kf4 0-1
#
#
# [Event "Riga sim"]
# [Site "Riga"]
# [Date "1909.??.??"]
# [Round "?"]
# [White "Lasker, Emanuel"]
# [Black "Bastin"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C67"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. O-O Be7 5. d4 Nxe4 6. Qe2 d5 7. Nxe5 Bd7 8. Nxd7 Qxd7 9. Re1 O-O 10. f3 Bh4 11. Bxc6 Qxc6 12. fxe4 Bxe1 13. Qxe1 Qxc2 14. Nc3 dxe4 15. Qxe4 Qxe4 16. Nxe4 Rad8 17. Nc5 Rxd4 18. Be3 Rd5 19. Nxb7 Rb8 20. Nc5 Rxb2 21. Nb3 a5 22. h3 Re2 23. Ba7 a4 24. Nd4 Rd2 25. Nf3 Rd1+ 26. Rxd1 Rxd1+ 27. Kf2 Ra1 28. Ke3 Rxa2 29. Nd2 Ra3+ 30. Ke2 Rb3 31. Kf2 Rd3 32. Ke2 Rd5 33. Nc4 a3 34. Nxa3 Ra5 35. Bb8 Rxa3 0-1
#
#
#
#
# (3) Pillsbury con 0.78 de similitud
#
# Partidas recomendadas:
#
# [Event "New York"]
# [Site "New York"]
# [Date "1894.??.??"]
# [Round "11"]
# [White "Pillsbury, Harry Nelson"]
# [Black "Steinitz, William"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "D26"]
#
# 1. d4 d5 2. c4 dxc4 3. Nf3 e6 4. e3 c5 5. Nc3 Nc6 6. Bxc4 Nf6 7. O-O cxd4 8. exd4 Be7 9. Bf4 O-O 10. Rc1 Qb6 11. Nb5 Ne8 12. Re1 Na5 13. Bd3 Bd7 14. Nc7 Rc8 15. Nd5 exd5 16. Rxe7 Nf6 17. Ng5 Bg4 18. Bxh7+ Nxh7 19. Qxg4 Rxc1+ 20. Bxc1 Nf6 21. Qd1 Nc6 22. Re1 Qxd4 23. Nf3 Qb6 24. Bg5 Qxb2 25. Re2 Qb5 26. Bxf6 gxf6 27. Rd2 Rd8 28. Nh4 d4 29. Rd3 Ne5 30. Rb3 Qc6 31. Rg3+ Kf8 32. Qd2 Rc8 33. Qh6+ Ke7 34. Nf5+ Kd7 35. h4 Qc1+ 36. Qxc1 Rxc1+ 37. Kh2 d3 0-1
#
#
# [Event "St Petersburg9596"]
# [Site "St Petersburg"]
# [Date "1895.??.??"]
# [Round "3"]
# [White "Chigorin, Mikhail"]
# [Black "Pillsbury, Harry Nelson"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C43"]
#
# 1. e4 e5 2. Nf3 Nf6 3. d4 exd4 4. e5 Ne4 5. Qxd4 d5 6. exd6 Nxd6 7. Nc3 Nc6 8. Qf4 Bf5 9. Bb5 Be7 10. Nd4 Bd7 11. Bxc6 Bxc6 12. Nxc6 bxc6 13. O-O O-O 14. Be3 Rb8 15. Rab1 Nc8 16. Qf3 Qd7 17. Rbd1 Bd6 18. b3 Qe6 19. Ne4 Ne7 20. Rfe1 Qg6 21. Bxa7 Rbe8 22. Nxd6 cxd6 23. c4 c5 24. Bb6 Nf5 25. Bc7 Nd4 26. Qd5 Ne2+ 27. Kf1 Nc3 28. Qxd6 Nxd1 29. Rxd1 Re6 30. Qd3 Qf6 31. a4 Rfe8 32. a5 Qe7 0-1
#
#
# [Event "London"]
# [Site "London"]
# [Date "1899.??.??"]
# [Round "25"]
# [White "Steinitz, William"]
# [Black "Pillsbury, Harry Nelson"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C29"]
#
# 1. e4 e5 2. Nc3 Nf6 3. f4 d5 4. d3 d4 5. Nce2 Nc6 6. Nf3 Bd6 7. c3 Bg4 8. fxe5 Bxe5 9. Nxe5 Nxe5 10. Qa4+ c6 11. Nxd4 Nh5 12. Qc2 c5 13. Nf5 Bxf5 14. exf5 O-O 15. Kf2 Qd7 16. Kg1 Qxf5 17. Be3 c4 18. Qf2 Qxf2+ 19. Kxf2 Rfe8 20. Bd4 Nxd3+ 21. Bxd3 cxd3 22. Rhe1 Nf4 23. Rxe8+ Rxe8 24. Re1 Rxe1 25. Kxe1 Nxg2+ 26. Kd2 a6 27. c4 Nh4 28. Kxd3 Nf3 29. Bc3 f6 30. Ke4 Nxh2 31. b4 Kf7 32. a4 Ke6 33. b5 Ng4 34. a5 Kd7 35. Bd4 h5 36. Kf5 Ne5 37. bxa6 bxa6 38. Bf2 g6+ 39. Kxf6 Ng4+ 40. Kxg6 Nxf2 41. Kxh5 Kc6 42. Kg5 Kc5 43. Kf4 Kxc4 44. Ke3 Nd3 45. Kd2 Nb4 46. Kc1 Kb3 0-1
#
#
# [Event "Paris"]
# [Site "Paris"]
# [Date "1900.??.??"]
# [Round "5"]
# [White "Didier, M1."]
# [Black "Pillsbury, Harry Nelson"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C67"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. O-O Nxe4 5. d4 Nd6 6. dxe5 Nxb5 7. a4 d6 8. e6 Bxe6 9. axb5 Ne5 10. Nd4 Bd7 11. Nc3 Be7 12. f4 Ng4 13. Nd5 O-O 14. f5 Nf6 15. Nxe7+ Qxe7 16. Re1 Qd8 17. Bg5 h6 18. Bh4 c5 19. bxc6 bxc6 20. Ra6 Qc8 21. Bxf6 gxf6 22. Ra3 Re8 23. Rf1 Re4 24. Qh5 Qf8 25. Ne2 d5 26. Ng3 Re5 27. Qh4 Qc5+ 28. Kh1 Qc4 29. Raf3 Qxh4 0-1
#
#
# [Event "Vienna Gambit"]
# [Site "Vienna"]
# [Date "1903.??.??"]
# [Round "?"]
# [White "Pillsbury, Harry Nelson"]
# [Black "Swiderski, Rudolf"]
# [Result "1-0"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C33"]
#
# 1. e4 e5 2. f4 exf4 3. Bc4 d5 4. Bxd5 Nf6 5. Nc3 Bb4 6. Nf3 O-O 7. O-O c6 8. Bc4 Qb6+ 9. d4 Bxc3 10. bxc3 Nxe4 11. Bxf4 Nd7 12. Qd3 Nef6 13. Bd6 Re8 14. Ng5 1-0
#
#
#
#
# (4) Steinitz con 0.76 de similitud
#
# Partidas recomendadas:
#
# [Event "London mt"]
# [Site "London"]
# [Date "1862.??.??"]
# [Round "?"]
# [White "Green, Valentine"]
# [Black "Steinitz, William"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "B40"]
#
# 1. e4 c5 2. Nf3 e6 3. Nc3 d5 4. exd5 exd5 5. d4 Be6 6. Bb5+ Nc6 7. O-O Nf6 8. Re1 Be7 9. Be3 Ng4 10. dxc5 Nxe3 11. fxe3 Bxc5 12. Nd4 Qd6 13. Nxe6 fxe6 14. Qg4 O-O 15. Bxc6 bxc6 16. Kh1 Rf2 17. Rad1 Raf8 18. h3 Qe5 19. e4 h5 20. Qh4 Bd6 21. g3 d4 22. Ne2 g5 23. Qxh5 Qxe4+ 0-1
#
#
# [Event "London mt"]
# [Site "London"]
# [Date "1862.??.??"]
# [Round "?"]
# [White "Green, Valentine"]
# [Black "Steinitz, William"]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C54"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bc4 Bc5 4. c3 Nf6 5. d4 exd4 6. cxd4 Bb4+ 7. Bd2 Bxd2+ 8. Nbxd2 d5 9. exd5 Nxd5 10. Qb3 Nce7 11. O-O O-O 12. Rfe1 Nf4 13. Re4 Neg6 14. Rae1 Bf5 15. R4e3 Qd6 16. Ne5 Nxe5 17. Rxe5 Bg6 18. Nf3 Kh8 19. Qe3 Nh5 20. Re8 Raxe8 21. Qxe8 Nf6 22. Qe7 h6 23. Qxd6 cxd6 24. h3 Re8 25. Rxe8+ Nxe8 26. Kf1 Kg8 27. Nd2 Kf8 28. Ke2 Ke7 29. Ke3 Nc7 30. f4 d5 31. Bd3 Bxd3 32. Kxd3 Kf6 33. Ke3 Ne6 34. Nf3 g5 35. g3 h5 36. fxg5+ Nxg5 37. Nxg5 Kxg5 38. Kf3 Kf5 39. Ke3 Kg5 40. Kf3 h4 41. g4 1/2-1/2
#
#
# [Event "London m-A6263"]
# [Site "London"]
# [Date "1863.??.??"]
# [Round "8"]
# [White "Blackburne, Joseph Henry"]
# [Black "Steinitz, William"]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C67"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. O-O Nxe4 5. Re1 Nd6 6. Nxe5 Be7 7. Ba4 Nxe5 8. Rxe5 O-O 9. d4 Bf6 10. Re1 Re8 11. c3 b5 12. Bc2 Bb7 13. Bf4 Rxe1+ 14. Qxe1 Qe8 15. Nd2 Qxe1+ 16. Rxe1 Re8 1/2-1/2
#
#
# [Event "London m2"]
# [Site "London"]
# [Date "1866.??.??"]
# [Round "14"]
# [White "Bird, Henry Edward"]
# [Black "Steinitz, William"]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C65"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. d4 Nxd4 5. Nxd4 exd4 6. e5 c6 7. O-O cxb5 8. Bg5 Be7 9. exf6 Bxf6 10. Re1+ Kf8 11. Bxf6 Qxf6 12. Qe2 g6 13. Nd2 d6 14. Qxb5 a6 15. Qd5 Bf5 16. Ne4 Bxe4 17. Rxe4 Kg7 18. g3 Rac8 19. Rf4 Qe6 20. Qxb7 Rxc2 21. Rd1 Qxa2 22. b3 Rf8 23. Qd5 1/2-1/2
#
#
# [Event "Vienna"]
# [Site "Vienna"]
# [Date "1873.??.??"]
# [Round "2"]
# [White "Steinitz, William"]
# [Black "Blackburne, Joseph Henry"]
# [Result "1/2-1/2"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C11"]
#
# 1. e4 e6 2. d4 d5 3. Nc3 Nf6 4. Bd3 c5 5. exd5 cxd4 6. Bb5+ Bd7 7. Qxd4 Bxb5 8. Nxb5 Nxd5 9. Ne2 Nc6 10. Qa4 a6 11. Nbd4 Nb6 12. Nxc6 Nxa4 13. Nxd8 Rxd8 14. O-O Be7 15. b3 Bf6 16. Rb1 Nc3 17. Nxc3 Bxc3 18. Ba3 f6 19. Rfd1 Kf7 20. Kf1 Ba5 21. Bd6 Rd7 22. Rd3 Rc8 23. b4 Bd8 24. Rb2 e5 25. Bc5 Rxd3 26. cxd3 b6 27. Be3 b5 28. Ke2 Be7 29. Bd2 Ke6 30. Kd1 Kd5 1/2-1/2
#
#
#
#
# (5) Zukertort con 0.76 de similitud
#
# Partidas recomendadas:
#
# [Event "Breslau m"]
# [Site "Breslau"]
# [Date "1864.??.??"]
# [Round "?"]
# [White "Zukertort, Johannes Hermann"]
# [Black "Anderssen, Adolf"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C65"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. O-O Be7 5. d4 exd4 6. e5 Ne4 7. Re1 Nc5 8. Nxd4 Nxd4 9. Qxd4 O-O 10. Nc3 a6 11. Bc4 b5 12. Bd5 c6 13. Bf3 Ne6 14. Qd3 f5 15. exf6 Bxf6 16. Ne4 d5 17. Nxf6+ Qxf6 18. c3 Bd7 19. Be3 Rae8 20. Bd4 Qh4 21. Be5 Ng5 22. Bg3 Qh6 23. Re3 Rxe3 24. Qxe3 Nxf3+ 25. gxf3 Qxe3 26. fxe3 Rxf3 27. Re1 Bh3 0-1
#
#
# [Event "GBR tour sim"]
# [Site "Great Britain"]
# [Date "1873.??.??"]
# [Round "?"]
# [White "Hunter, Jenkins"]
# [Black "Zukertort, Johannes Hermann"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C45"]
#
# 1. e4 e5 2. Nf3 Nc6 3. d4 exd4 4. Nxd4 Qh4 5. Nf3 Qxe4+ 6. Be2 Bb4+ 7. c3 Be7 8. O-O Nf6 9. Re1 O-O 10. Bd3 Qg4 11. h3 Qh5 12. Nbd2 d5 13. Nf1 Bd6 14. Ng3 Bxg3 15. fxg3 d4 16. Bg5 dxc3 17. bxc3 h6 18. g4 Bxg4 19. hxg4 Nxg4 20. Be3 Rad8 21. Qc2 Nce5 22. Bf5 Nxf3+ 23. gxf3 Nxe3 24. Rxe3 Qg5+ 25. Kf2 Rd5 26. Bd3 Qh4+ 27. Ke2 Qh2+ 28. Ke1 Qg1+ 0-1
#
#
# [Event "Leipzig"]
# [Site "Leipzig"]
# [Date "1877.??.??"]
# [Round "9"]
# [White "Metger, Johannes"]
# [Black "Zukertort, Johannes Hermann"]
# [Result "0-1"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C44"]
#
# 1. e4 e5 2. Nf3 Nc6 3. d4 exd4 4. c3 dxc3 5. Bc4 Nf6 6. Ng5 Ne5 7. Bb3 d5 8. exd5 Bb4 9. O-O O-O 10. Nxc3 h6 11. Nge4 Nxe4 12. Nxe4 Qh4 13. Qd4 Bd6 14. f4 Ng4 15. h3 Nf6 16. Nxf6+ gxf6 17. Bc2 Bxh3 18. Qd3 Bc5+ 19. Be3 Bf5 20. Qd2 Bxe3+ 21. Qxe3 Bxc2 22. Rf3 Bf5 23. Raf1 Bg4 24. Rg3 f5 25. Rff3 Qf6 0-1
#
#
# [Event "DSB-05.Kongress"]
# [Site "Frankfurt"]
# [Date "1887.??.??"]
# [Round "15"]
# [White "Burn, Amos"]
# [Black "Zukertort, Johannes Hermann"]
# [Result "1-0"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "D26"]
#
# 1. d4 d5 2. c4 e6 3. Nc3 Nf6 4. Bf4 c5 5. e3 cxd4 6. exd4 Nc6 7. Nf3 dxc4 8. Bxc4 Be7 9. O-O O-O 10. Rc1 Bd7 11. Qe2 Rc8 12. Rfd1 Na5 13. Bd3 Bc6 14. Ne5 Qb6 15. Be3 Bd5 16. g4 Rfd8 17. g5 Rxc3 18. bxc3 Ne4 19. c4 1-0
#
#
# [Event "DSB-05.Kongress"]
# [Site "Frankfurt"]
# [Date "1887.??.??"]
# [Round "20"]
# [White "Tarrasch, Siegbert"]
# [Black "Zukertort, Johannes Hermann"]
# [Result "1-0"]
# [WhiteElo ""]
# [BlackElo ""]
# [ECO "C83"]
#
# 1. e4 e5 2. Nf3 Nc6 3. Bb5 Nf6 4. O-O Nxe4 5. d4 a6 6. Ba4 b5 7. Bb3 d5 8. dxe5 Be6 9. c3 Be7 10. Re1 O-O 11. Nd4 Qd7 12. Nxe6 fxe6 13. Rxe4 Bc5 14. Be3 Bxe3 15. Rxe3 Rf5 16. Bc2 Rf7 17. Nd2 1-0
