# %%
#!pip install umap-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import umap 

data = pd.read_csv("csvs\embeddings_e5_large_v2.csv")
data
# Out:
# C:\Users\B\AppData\Local\Temp\ipykernel_20068\349897435.py:6: DtypeWarning: Columns (1,2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("csvs\embeddings_e5_large_v2.csv")
#         id    player  color  \
# 0      0.0  Alekhine  black
# 1      1.0  Alekhine  black
# 2      2.0  Alekhine  white
# 3      3.0  Alekhine  white
# 4      4.0  Alekhine  black
# ...    ...       ...    ...
# 99892  NaN       NaN    NaN
# 99893  NaN       NaN    NaN
# 99894  NaN       NaN    NaN
# 99895  NaN       NaN    NaN
# 99896  NaN       NaN    NaN
#
#                                                    moves     dim_0     dim_1  \
# 0      e5 Bc5 d6 Bg4 Bxf3 Nc6 Bb6 Nce7 exd4 Nf6 O-O d... -0.005262 -0.040441
# 1      e5 Nc6 exd4 Nf6 Bb4 bxc6 Qe7 d5 O-O Bc5 gxf6 B... -0.007092 -0.046165
# 2      e4 Nf3 Bc4 Ng5 exd5 Bb5+ dxc6 Qf3 Bd3 Ne4 Ng3 ...  0.001824 -0.037218
# 3      e4 Ne2 Ng3 Nc3 Qf3 exf5 Nce4 c3 d4 Nh5 Nhf6+ g...  0.000311 -0.048322
# 4      e5 Nc6 Bc5 Bxb4 Ba5 exd4 dxc3 Qf6 Qg6 Nge7 Rb8...  0.002891 -0.039766
# ...                                                  ...       ...       ...
# 99892                                                NaN  0.004741 -0.054427
# 99893                                                NaN -0.005351 -0.056085
# 99894                                                NaN -0.013228 -0.045450
# 99895                                                NaN -0.008823 -0.055997
# 99896                                                NaN -0.008686 -0.038392
#
#           dim_2     dim_3     dim_4     dim_5  ...  dim_1014  dim_1015  \
# 0      0.031833 -0.005094 -0.031355  0.022226  ... -0.015199 -0.000572
# 1      0.036690  0.000193 -0.043738  0.029980  ... -0.014564  0.000565
# 2      0.029389  0.009539 -0.044505  0.026463  ... -0.019309  0.001417
# 3      0.024010  0.005462 -0.037319  0.036435  ... -0.007638  0.002743
# 4      0.031097 -0.003850 -0.032993  0.022699  ... -0.016726 -0.006898
# ...         ...       ...       ...       ...  ...       ...       ...
# 99892  0.042252  0.000138 -0.028160  0.029607  ... -0.024891 -0.005963
# 99893  0.026406 -0.008013 -0.042267  0.039302  ... -0.014585  0.009580
# 99894  0.030372 -0.016128 -0.034693  0.017748  ... -0.018758  0.010402
# 99895  0.037359  0.006382 -0.049256  0.034817  ... -0.027640  0.005097
# 99896  0.028953 -0.003274 -0.038615  0.023900  ... -0.012265 -0.003219
#
#        dim_1016  dim_1017  dim_1018  dim_1019  dim_1020  dim_1021  dim_1022  \
# 0      0.033563  0.035960  0.032606 -0.042754  0.044466 -0.063672  0.011189
# 1      0.015152  0.046204  0.042341 -0.035781  0.040620 -0.050702  0.010596
# 2      0.020511  0.047450  0.042363 -0.035716  0.032159 -0.051947  0.021027
# 3      0.028606  0.040824  0.029878 -0.024778  0.041490 -0.049448  0.024498
# 4      0.029117  0.041884  0.043342 -0.036410  0.033101 -0.060705  0.013159
# ...         ...       ...       ...       ...       ...       ...       ...
# 99892  0.018998  0.055783  0.055897 -0.043188  0.048086 -0.057328  0.025243
# 99893  0.018593  0.048559  0.065928 -0.050039  0.038075 -0.040041  0.015492
# 99894  0.028746  0.049686  0.043673 -0.032612  0.061842 -0.068508  0.015561
# 99895  0.009673  0.053134  0.036317 -0.036176  0.042099 -0.055249  0.025980
# 99896  0.018113  0.061026  0.037726 -0.033230  0.044609 -0.048643  0.016793
#
#        dim_1023
# 0      0.045771
# 1      0.029212
# 2      0.036685
# 3      0.026151
# 4      0.050347
# ...         ...
# 99892  0.046252
# 99893  0.047887
# 99894  0.028104
# 99895  0.035002
# 99896  0.041338
#
# [99897 rows x 1028 columns]

# %%
#dropear nulos en cualquiera de las columnas
data = data.dropna(axis=0, how='any')

# %%
# Define las columnas de embedding
embedding_columns = [f"dim_{i}" for i in range(1024)]

# Crea la columna "moves" como arrays de NumPy
data["moves"] = data[embedding_columns].values.tolist()

# (Opcional) Si ya no necesitas las columnas individuales, puedes borrarlas
data.drop(columns=embedding_columns, inplace=True)

data
# Out:
# C:\Users\B\AppData\Local\Temp\ipykernel_20068\3476630556.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["moves"] = data[embedding_columns].values.tolist()
# C:\Users\B\AppData\Local\Temp\ipykernel_20068\3476630556.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=embedding_columns, inplace=True)
#             id     player  color  \
# 0          0.0   Alekhine  black
# 1          1.0   Alekhine  black
# 2          2.0   Alekhine  white
# 3          3.0   Alekhine  white
# 4          4.0   Alekhine  black
# ...        ...        ...    ...
# 99706  99799.0  Zukertort  white
# 99707  99800.0  Zukertort  white
# 99708  99801.0  Zukertort  black
# 99709  99802.0  Zukertort  black
# 99710  99803.0  Zukertort  white
#
#                                                    moves
# 0      [-0.005261869, -0.040441096, 0.031833284, -0.0...
# 1      [-0.007091814, -0.04616487, 0.036690176, 0.000...
# 2      [0.001824152, -0.037217766, 0.02938916, 0.0095...
# 3      [0.00031143514, -0.048322093, 0.024009915, 0.0...
# 4      [0.0028905096, -0.03976597, 0.03109679, -0.003...
# ...                                                  ...
# 99706  [-0.014731857, -0.058038216, 0.02144021, -0.00...
# 99707  [-0.005562681, -0.04928391, 0.036888875, -0.00...
# 99708  [-0.003597049, -0.046891447, 0.034446366, -0.0...
# 99709  [-0.0022927453, -0.041619875, 0.032001715, -0....
# 99710  [-0.008379885, -0.045661353, 0.025401812, 0.01...
#
# [99711 rows x 4 columns]

# %%
X = np.stack(data["moves"].values)

# %%
import umap
import matplotlib.pyplot as plt

# Reducir a 2D para visualizar
umap_model = umap.UMAP(n_components=2, random_state=3633)
X_2d = umap_model.fit_transform(X)


# Mapear color: white → gris claro, black → negro
color_map = {"white": "yellow", "black": "purple"}
colors = data["color"].map(color_map)

# Graficar
plt.figure(figsize=(8, 6))
plt.scatter(X_2d[:, 0], X_2d[:, 1], c=colors, s=10)
plt.title("Embeddings de partidas por color")
plt.xlabel("Componente 1")
plt.ylabel("Componente 2")
plt.grid(True)
plt.show()
# Out:
# c:\Users\B\AppData\Local\Programs\Python\Python38\lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

sse = []
for k in range(2, 17):
    kmeans = KMeans(n_clusters=k, random_state=3633)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

plt.plot(range(2, 17), sse, marker="o")
plt.xlabel("Número de clusters")
plt.ylabel("SSE (Inercia)")
plt.title("Método del codo")
plt.show()

# %%
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def kmeans_player_identification_with_errors_v3(X_train, train_df, X_test, test_df, k_values):
    results = []
    all_errors = []
    accuracies = []

    for k in k_values:
        print(f"\nEvaluando K = {k}...")

        kmeans = KMeans(n_clusters=k, random_state=3633)
        kmeans.fit(X_train)

        # Asignar clusters
        train_df = train_df.copy()
        train_df["cluster"] = kmeans.labels_
        test_labels = kmeans.predict(X_test)
        test_df = test_df.copy()
        test_df["cluster"] = test_labels

        # Distribución de clusters por jugador
        cluster_dist_train = pd.crosstab(train_df["player"], train_df["cluster"], normalize="index")
        cluster_dist_test = pd.crosstab(test_df["player"], test_df["cluster"], normalize="index")

        # Asegurar misma estructura
        cluster_dist_test = cluster_dist_test.reindex(columns=cluster_dist_train.columns, fill_value=0)

        players_train = cluster_dist_train.index.tolist()
        players_test = cluster_dist_test.index.tolist()

        train_vectors = cluster_dist_train.values
        test_vectors = cluster_dist_test.values

        # Comparar vectores
        sim_matrix = cosine_similarity(test_vectors, train_vectors)
        pred_indices = sim_matrix.argmax(axis=1)
        pred_players = [players_train[idx] for idx in pred_indices]

        # Evaluar
        df_compare = pd.DataFrame({
            "player": players_test,
            "pred_player": pred_players
        })
        df_compare["correct"] = df_compare["player"] == df_compare["pred_player"]
        accuracy_global = df_compare["correct"].mean()*100
        accuracies.append(df_compare["correct"].mean())


        print(f"Accuracy para K={k}: {accuracy_global:.2f}%")

        # Mostrar errores
        errors = df_compare[df_compare["correct"] == False].copy()


        # Guardar resultados
        for player, group in df_compare.groupby("player"):
            acc = group["correct"].mean() * 100
            results.append({"k": k, "player": player, "accuracy_%": acc})

        errors["k"] = k
        all_errors.append(errors)

    results_df = pd.DataFrame(results)
    errors_df = pd.concat(all_errors, ignore_index=True)

    return accuracies, results_df, errors_df

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

# 1. Convertir la columna "moves" a numpy arrays (si no lo están)
# Si tus embeddings están guardados como strings tipo '[0.1, 0.2, ...]', usa ast.literal_eval
import ast

def safe_to_array(x):
    if isinstance(x, str):
        return np.array(ast.literal_eval(x))
    elif isinstance(x, list):
        return np.array(x)
    elif isinstance(x, np.ndarray):
        return x
    else:
        raise ValueError("Formato inesperado en 'moves'")

data["embedding"] = data["moves"].apply(safe_to_array)

# 2. Apilar embeddings en matriz 2D para sklearn
X = np.stack(data["embedding"].values)

# 3. Extraer vector player (labels)
y = data["player"].values

# 4. Separar en train y test, manteniendo proporciones de jugadores (stratify)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3633, stratify=y)

#contras cuantos hay de cada jugador
print(pd.Series(y_test).value_counts())
# Out:
# C:\Users\B\AppData\Local\Temp\ipykernel_20068\1523865472.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["embedding"] = data["moves"].apply(safe_to_array)
# Kamsky         1407
# Carlsen        1323
# Caruana        1068
# Aronian        1021
# Ivanchuk        990
# Kramnik         865
# Anand           840
# Gelfand         794
# Timman          723
# Karjakin        707
# Karpov          706
# Portisch        606
# Leko            536
# Smyslov         524
# Topalov         522
# Tal             486
# Larsen          475
# Spassky         446
# Geller          439
# Kasparov        425
# Bronstein       386
# Polugaevsky     378
# Petrosian       378
# Alekhine        332
# Najdorf         320
# Keres           314
# Reshevsky       253
# Euwe            224
# Korchnoi        207
# Bogoljubow      194
# Lasker          180
# Botvinnik       178
# Fischer         165
# Rubinstein      159
# Maroczy         151
# Schlechter      148
# Tarrasch        141
# Chigorin        137
# Anderssen       136
# Capablanca      119
# Steinitz        118
# Nimzowitsch     102
# Pillsbury        77
# Fine             61
# Staunton         57
# Winawer          48
# Morphy           42
# Zukertort        34
# Philidor          1
# dtype: int64

# %%
# 1. Crear dataframes con la info de train/test, asegurándote que y_train y y_test estén definidos y alineados con X_train y X_test
train_df = pd.DataFrame({"player": y_train})
test_df = pd.DataFrame({"player": y_test})

# %%
# 2. Definir la lista de valores K que quieres probar
k_values = list(range(2, 62, 2))
accuracies, df_results, df_errors = kmeans_player_identification_with_errors_v3(X_train, train_df, X_test, test_df, k_values)
# Out:
# Evaluando K = 2...
# Accuracy para K=2: 2.04%
#
# Evaluando K = 4...
# Accuracy para K=4: 14.29%
#
# Evaluando K = 6...
# Accuracy para K=6: 32.65%
#
# Evaluando K = 8...
# Accuracy para K=8: 40.82%
#
# Evaluando K = 10...
# Accuracy para K=10: 48.98%
#
# Evaluando K = 12...
# Accuracy para K=12: 48.98%
#
# Evaluando K = 14...
# Accuracy para K=14: 59.18%
#
# Evaluando K = 16...
# Accuracy para K=16: 57.14%
#
# Evaluando K = 18...
# Accuracy para K=18: 67.35%
#
# Evaluando K = 20...
# Accuracy para K=20: 65.31%
#
# Evaluando K = 22...
# Accuracy para K=22: 71.43%
#
# Evaluando K = 24...
# Accuracy para K=24: 85.71%
#
# Evaluando K = 26...
# Accuracy para K=26: 79.59%
#
# Evaluando K = 28...
# Accuracy para K=28: 77.55%
#
# Evaluando K = 30...
# Accuracy para K=30: 81.63%
#
# Evaluando K = 32...
# Accuracy para K=32: 77.55%
#
# Evaluando K = 34...
# Accuracy para K=34: 83.67%
#
# Evaluando K = 36...
# Accuracy para K=36: 79.59%
#
# Evaluando K = 38...
# Accuracy para K=38: 75.51%
#
# Evaluando K = 40...
# Accuracy para K=40: 77.55%
#
# Evaluando K = 42...
# Accuracy para K=42: 77.55%
#
# Evaluando K = 44...
# Accuracy para K=44: 81.63%
#
# Evaluando K = 46...
# Accuracy para K=46: 81.63%
#
# Evaluando K = 48...
# Accuracy para K=48: 81.63%
#
# Evaluando K = 50...
# Accuracy para K=50: 79.59%
#
# Evaluando K = 52...
# Accuracy para K=52: 75.51%
#
# Evaluando K = 54...
# Accuracy para K=54: 83.67%
#
# Evaluando K = 56...
# Accuracy para K=56: 81.63%
#
# Evaluando K = 58...
# Accuracy para K=58: 77.55%
#
# Evaluando K = 60...
# Accuracy para K=60: 75.51%

# %%
plt.figure(figsize=(8, 5))
plt.plot(k_values, accuracies, marker='o', linestyle='-', color='blue')
plt.title("Accuracy vs Número de Clusters (k)")
plt.xlabel("Número de Clusters (k)")
plt.ylabel("Accuracy")
plt.grid(True)
plt.xticks(k_values)
plt.show()

# %%
error_counts = df_errors.groupby("player")["correct"].apply(lambda x: (~x).sum()).sort_values(ascending=False)
error_counts
# Out:
# player
# Nimzowitsch    30
# Zukertort      29
# Winawer        27
# Botvinnik      27
# Philidor       27
# Pillsbury      26
# Morphy         24
# Reshevsky      23
# Lasker         21
# Euwe           19
# Fine           19
# Smyslov        16
# Capablanca     15
# Bogoljubow     15
# Korchnoi       13
# Rubinstein     12
# Carlsen        11
# Chigorin       10
# Gelfand         8
# Kramnik         7
# Maroczy         6
# Karjakin        6
# Staunton        6
# Anand           5
# Schlechter      5
# Geller          5
# Najdorf         5
# Fischer         5
# Bronstein       5
# Keres           4
# Spassky         4
# Steinitz        4
# Tarrasch        4
# Polugaevsky     4
# Portisch        4
# Tal             3
# Larsen          3
# Kamsky          3
# Ivanchuk        3
# Leko            2
# Caruana         2
# Aronian         2
# Timman          2
# Topalov         2
# Anderssen       2
# Petrosian       1
# Kasparov        1
# Karpov          1
# Alekhine        1
# Name: correct, dtype: int64

# %%
#Mejor Modelo
from sklearn.cluster import KMeans


kmeans = KMeans(n_clusters=24, random_state=3633)
kmeans.fit(X_train)

train_df = train_df.copy()
train_df["cluster"] = kmeans.labels_


cluster_dist_train = pd.crosstab(train_df["player"], train_df["cluster"], normalize="index")
cluster_dist_train
# Out:
# cluster            0         1         2         3         4         5   \
# player
# Alekhine     0.015083  0.032428  0.052036  0.055053  0.042232  0.074661
# Anand        0.005653  0.061589  0.055341  0.068134  0.087771  0.038976
# Anderssen    0.051471  0.051471  0.018382  0.053309  0.056985  0.031250
# Aronian      0.010037  0.047491  0.056548  0.056793  0.040881  0.061200
# Bogoljubow   0.008997  0.051414  0.053985  0.071979  0.025707  0.077121
# Botvinnik    0.004208  0.056101  0.093969  0.061711  0.014025  0.068724
# Bronstein    0.005188  0.051232  0.066796  0.068093  0.043450  0.043450
# Capablanca   0.012552  0.033473  0.052301  0.079498  0.052301  0.064854
# Carlsen      0.022873  0.065595  0.044423  0.046314  0.053119  0.064650
# Caruana      0.022009  0.059939  0.061812  0.039101  0.074221  0.051276
# Chigorin     0.016364  0.025455  0.067273  0.045455  0.029091  0.036364
# Euwe         0.005574  0.043478  0.070234  0.079153  0.021182  0.088071
# Fine         0.004115  0.032922  0.074074  0.111111  0.028807  0.057613
# Fischer      0.013636  0.069697  0.048485  0.057576  0.086364  0.040909
# Gelfand      0.004094  0.083780  0.076220  0.051969  0.009134  0.086929
# Geller       0.003986  0.051253  0.055239  0.046697  0.044989  0.052961
# Ivanchuk     0.008588  0.063905  0.061884  0.054559  0.033847  0.051528
# Kamsky       0.031805  0.078181  0.058991  0.029673  0.041045  0.052772
# Karjakin     0.010262  0.040694  0.052371  0.054494  0.069710  0.041401
# Karpov       0.006378  0.036499  0.083274  0.055280  0.021262  0.078668
# Spassky      0.014029  0.042088  0.046577  0.041526  0.084736  0.057239
# Staunton     0.044248  0.017699  0.004425  0.017699  0.044248  0.119469
# Steinitz     0.029724  0.095541  0.012739  0.012739  0.095541  0.070064
# Tal          0.016993  0.022657  0.030381  0.060247  0.054583  0.074150
# Tarrasch     0.021352  0.021352  0.012456  0.044484  0.115658  0.046263
# Timman       0.021424  0.041465  0.028680  0.093296  0.069454  0.043884
# Topalov      0.025371  0.045955  0.020105  0.062709  0.092867  0.032073
# Winawer      0.036649  0.036649  0.010471  0.020942  0.125654  0.041885
# Zukertort    0.065693  0.058394  0.007299  0.021898  0.124088  0.058394
#
# cluster            22        23
# player
# Alekhine     0.024887  0.016591
# Anand        0.022017  0.023505
# Anderssen    0.009191  0.047794
# Aronian      0.043574  0.019584
# Bogoljubow   0.046272  0.014139
# Botvinnik    0.056101  0.023843
# Bronstein    0.022698  0.023346
# Capablanca   0.043933  0.014644
# Carlsen      0.034216  0.011720
# Caruana      0.029970  0.012175
# Chigorin     0.020000  0.012727
# Euwe         0.049052  0.018952
# Fine         0.057613  0.004115
# Fischer      0.027273  0.013636
# Gelfand      0.059213  0.018268
# Geller       0.031891  0.009112
# Ivanchuk     0.044203  0.025259
# Kamsky       0.033582  0.015991
# Karjakin     0.024770  0.020524
# Karpov       0.053154  0.022325
# Kasparov     0.053467  0.017039
# Keres        0.024682  0.020701
# Korchnoi     0.053076  0.034982
# Kramnik      0.050029  0.018797
# Larsen       0.060988  0.021030
# Lasker       0.023644  0.022253
# Leko         0.018674  0.019608
# Maroczy      0.038143  0.014925
# Morphy       0.011905  0.011905
# Najdorf      0.070203  0.010140
# Nimzowitsch  0.024450  0.022005
# Petrosian    0.045575  0.030383
# Philidor     0.000000  0.000000
# Pillsbury    0.006452  0.029032
# Polugaevsky  0.076770  0.017869
# Portisch     0.061494  0.022699
# Reshevsky    0.061265  0.015810
# Rubinstein   0.043956  0.020408
# Schlechter   0.023729  0.011864
# Smyslov      0.060534  0.020496
# Spassky      0.021886  0.017957
# Staunton     0.035398  0.013274
# Steinitz     0.027601  0.038217
# Tal          0.022657  0.020082
# Tarrasch     0.019573  0.019573
# Timman       0.040428  0.018659
# Topalov      0.035902  0.019627
# Winawer      0.005236  0.010471
# Zukertort    0.014599  0.000000
#
# [49 rows x 24 columns]

# %%
X_players = cluster_dist_train.values
X_labels = cluster_dist_train.index.tolist()
X_labels
# Out:
# ['Alekhine',
#  'Anand',
#  'Anderssen',
#  'Aronian',
#  'Bogoljubow',
#  'Botvinnik',
#  'Bronstein',
#  'Capablanca',
#  'Carlsen',
#  'Caruana',
#  'Chigorin',
#  'Euwe',
#  'Fine',
#  'Fischer',
#  'Gelfand',
#  'Geller',
#  'Ivanchuk',
#  'Kamsky',
#  'Karjakin',
#  'Karpov',
#  'Kasparov',
#  'Keres',
#  'Korchnoi',
#  'Kramnik',
#  'Larsen',
#  'Lasker',
#  'Leko',
#  'Maroczy',
#  'Morphy',
#  'Najdorf',
#  'Nimzowitsch',
#  'Petrosian',
#  'Philidor',
#  'Pillsbury',
#  'Polugaevsky',
#  'Portisch',
#  'Reshevsky',
#  'Rubinstein',
#  'Schlechter',
#  'Smyslov',
#  'Spassky',
#  'Staunton',
#  'Steinitz',
#  'Tal',
#  'Tarrasch',
#  'Timman',
#  'Topalov',
#  'Winawer',
#  'Zukertort']

# %%
import pandas as pd


df = cluster_dist_train.copy()
df['player'] = df.index.to_series().str.split().str[-1]
cols = ['player'] + [col for col in df.columns if col != 'player']
df = df[cols]

# Guardar como CSV
df.to_csv("csvs/player_embeddings.csv", index=False)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reducir a 2 dimensiones
pca = PCA(n_components=2)
X_players_2d = pca.fit_transform(cluster_dist_train.values)

# Graficar
plt.figure(figsize=(8, 6))
plt.scatter(X_players_2d[:, 0], X_players_2d[:, 1])
plt.title("Visualización de jugadores (PCA)")
plt.xlabel("Componente principal 1")
plt.ylabel("Componente principal 2")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reducir a 2D con PCA
pca = PCA(n_components=2)
X_players_2d = pca.fit_transform(cluster_dist_train.values)

plt.figure(figsize=(20, 15))

# Dibujar puntos con menor opacidad
plt.scatter(X_players_2d[:, 0], X_players_2d[:, 1], s=50, alpha=0.5, color="gray")

# Escribir nombre en la misma posición (centrado)
for i, name in enumerate(cluster_dist_train.index):
    plt.text(
        X_players_2d[i, 0],
        X_players_2d[i, 1],
        name,
        fontsize=12,
        ha="center",
        va="center",
        alpha=0.9
    )

plt.title("Jugadores representados en 2D (PCA)", fontsize=18)
plt.xlabel("Componente principal 1", fontsize=14)
plt.ylabel("Componente principal 2", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.3)
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Usamos los vectores de distribución de clusters por jugador
X = cluster_dist_train.values

inertias = []
k_values = range(1, 10)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

# Graficar el método del codo
plt.figure(figsize=(10, 6))
plt.plot(k_values, inertias, 'bo-')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Inercia')
plt.title('Método del codo para determinar k óptimo')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans_final = KMeans(n_clusters=10, random_state=3633)
cluster_labels = kmeans_final.fit_predict(cluster_dist_train)

# Añadir los resultados al DataFrame
clustered_players = cluster_dist_train.copy()
clustered_players["cluster"] = cluster_labels

# %%
for cluster_id in sorted(clustered_players["cluster"].unique()):
    print(f"\nCluster {cluster_id}:")
    print(clustered_players[clustered_players["cluster"] == cluster_id].index.tolist())
# Out:
# Cluster 0:
# ['Winawer', 'Zukertort']
#
# Cluster 1:
# ['Aronian', 'Bogoljubow', 'Botvinnik', 'Carlsen', 'Gelfand', 'Ivanchuk', 'Kamsky', 'Kasparov', 'Korchnoi', 'Kramnik', 'Larsen', 'Nimzowitsch', 'Rubinstein', 'Timman', 'Topalov']
#
# Cluster 2:
# ['Philidor']
#
# Cluster 3:
# ['Morphy']
#
# Cluster 4:
# ['Bronstein', 'Geller', 'Keres', 'Spassky', 'Tal']
#
# Cluster 5:
# ['Anand', 'Caruana', 'Fischer', 'Karjakin', 'Leko', 'Maroczy', 'Tarrasch']
#
# Cluster 6:
# ['Alekhine', 'Chigorin', 'Lasker', 'Pillsbury', 'Schlechter', 'Steinitz']
#
# Cluster 7:
# ['Anderssen', 'Staunton']
#
# Cluster 8:
# ['Karpov', 'Najdorf', 'Petrosian', 'Polugaevsky', 'Portisch', 'Reshevsky', 'Smyslov']
#
# Cluster 9:
# ['Capablanca', 'Euwe', 'Fine']

# %%
#Quitamos outliers
cluster_dist_train_clean = cluster_dist_train.drop(["Philidor", "Morphy"], errors="ignore")

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Usamos los vectores de distribución de clusters por jugador
X = cluster_dist_train_clean.values

inertias = []
k_values = range(1, 10)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertias.append(kmeans.inertia_)

# Graficar el método del codo
plt.figure(figsize=(10, 6))
plt.plot(k_values, inertias, 'bo-')
plt.xlabel('Número de clusters (k)')
plt.ylabel('Inercia')
plt.title('Método del codo para determinar k óptimo')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans_final = KMeans(n_clusters=6, random_state=3633)
cluster_labels = kmeans_final.fit_predict(cluster_dist_train_clean)

# Añadir los resultados al DataFrame
clustered_players = cluster_dist_train_clean.copy()
clustered_players["cluster"] = cluster_labels

# %%
for cluster_id in sorted(clustered_players["cluster"].unique()):
    print(f"\nCluster {cluster_id}:")
    print(clustered_players[clustered_players["cluster"] == cluster_id].index.tolist())
# Out:
# Cluster 0:
# ['Anand', 'Fischer', 'Keres', 'Lasker', 'Leko', 'Maroczy', 'Tal', 'Tarrasch']
#
# Cluster 1:
# ['Botvinnik', 'Gelfand', 'Ivanchuk', 'Karpov', 'Kasparov', 'Korchnoi', 'Kramnik', 'Larsen']
#
# Cluster 2:
# ['Aronian', 'Carlsen', 'Caruana', 'Kamsky', 'Karjakin', 'Topalov']
#
# Cluster 3:
# ['Anderssen', 'Chigorin', 'Pillsbury', 'Schlechter', 'Staunton', 'Steinitz', 'Winawer', 'Zukertort']
#
# Cluster 4:
# ['Bronstein', 'Geller', 'Najdorf', 'Petrosian', 'Polugaevsky', 'Portisch', 'Reshevsky', 'Smyslov', 'Spassky']
#
# Cluster 5:
# ['Alekhine', 'Bogoljubow', 'Capablanca', 'Euwe', 'Fine', 'Nimzowitsch', 'Rubinstein', 'Timman']

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Supongamos que tienes un DataFrame cluster_dist_train con las características (sin la columna cluster)
# y una serie cluster_labels con la etiqueta de cluster para cada jugador (index coincide)

# Extraemos los datos numéricos para TSNE (sin la columna cluster)
X = clustered_players.drop(columns=['cluster'])

# Aplicar TSNE para reducción a 2D
tsne = TSNE(n_components=2, random_state=42)
X_embedded = tsne.fit_transform(X)

# Ahora hacemos el scatter plot con colores por cluster
clusters = clustered_players['cluster'].values
unique_clusters = sorted(set(clusters))

plt.figure(figsize=(10,8))
for clust in unique_clusters:
    idx = clusters == clust
    plt.scatter(X_embedded[idx, 0], X_embedded[idx, 1], label=f'Cluster {clust}', alpha=0.7)

# Opcional: agregar nombres de los jugadores para no perder la referencia
for i, player in enumerate(clustered_players.index):
    plt.text(X_embedded[i, 0], X_embedded[i, 1], player, fontsize=8, alpha=0.75)

plt.legend()
plt.title('Visualización 2D de clusters con t-SNE')
plt.xlabel('Dim 1')
plt.ylabel('Dim 2')
plt.show()
# Out:
# c:\Users\B\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\B\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
import pickle

# Guardar modelo
with open('modelos\kmeans_games.pkl', 'wb') as f:
    pickle.dump(kmeans, f)

with open('modelos\kmeans_players.pkl', 'wb') as f:
    pickle.dump(kmeans_final, f)
